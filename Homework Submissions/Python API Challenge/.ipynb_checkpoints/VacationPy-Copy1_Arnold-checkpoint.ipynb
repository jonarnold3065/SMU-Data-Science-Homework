# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import time
import json


import seaborn as sns
import scipy.stats as stats
from census import Census
from IPython.display import display
import ipywidgets as widgets
import gmaps.geojson_geometries


# Import API key
from config import g_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1e5cd66face7> in <module>
#      19
#      20 # Import API key
# ---> 21 from config import g_key
#
# ModuleNotFoundError: No module named 'config'

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
filepath = "../output_data/cities.csv"
base_df = pd.read_csv(filepath)
base_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
renamed_df = base_df.rename(columns={'Unnamed: 0': 'City ID', 'Max Temp': 'MaxTemp'})
renamed_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  MaxTemp  Wind Speed
# 0   39.51    37.50        7.16
# 1   57.70    78.80       11.41
# 2  -69.36    22.20        2.37
# 3  112.04    44.60        4.47
# 4   18.42    55.99        8.05

# %%
renamed_df.MaxTemp.max()
# Out:
# 104.1

# %%
gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
renamed_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  MaxTemp  Wind Speed
# 0   39.51    37.50        7.16
# 1   57.70    78.80       11.41
# 2  -69.36    22.20        2.37
# 3  112.04    44.60        4.47
# 4   18.42    55.99        8.05

# %%
cleaned_df = renamed_df.dropna(subset=["Lat","Lng"])
cleaned_df
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  MaxTemp  Wind Speed
# 0     39.51    37.50        7.16
# 1     57.70    78.80       11.41
# 2    -69.36    22.20        2.37
# 3    112.04    44.60        4.47
# 4     18.42    55.99        8.05
# ..      ...      ...         ...
# 543   36.66    80.60        8.05
# 544 -104.61    84.20       16.11
# 545    0.71    61.00        8.05
# 546  132.56    49.74        2.68
# 547  109.18    55.86        2.84
#
# [548 rows x 10 columns]

# %%
# build gmap criteria

# %%
# build google maps heatmap criteria 

figure_layout = {
    'width': '800px',
    'height': '400px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

 

fig = gmaps.figure(map_type="HYBRID", layout=figure_layout)
heatmap_layer = gmaps.heatmap_layer(
    cleaned_df[['Lat', 'Lng']], weights=cleaned_df['Humidity'],
    max_intensity=500, point_radius=10, dissipating = False
)
fig.add_layer(heatmap_layer)



# fig.add_layer(gmaps.traffic_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='400px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
cleaned_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  MaxTemp  Wind Speed
# 0   39.51    37.50        7.16
# 1   57.70    78.80       11.41
# 2  -69.36    22.20        2.37
# 3  112.04    44.60        4.47
# 4   18.42    55.99        8.05

# %%
# Out:
# 36.03

# %%
# add more filtering criteria for the very best vacation spots!

mask1 = (cleaned_df['MaxTemp'] < 80) & (cleaned_df['MaxTemp'] > 70)
mask2 = cleaned_df["Wind Speed"] < 10
mask3 = cleaned_df.Cloudiness < 10

df_sub = cleaned_df.loc[mask1 & mask2 & mask3].reset_index(drop=True)
df_sub = df_sub.dropna(how="any")
df_sub
# Out:
#     City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 1        70  ponta do sol           0      BR  1558378767        57 -20.63
# 2        87      ambilobe           2      MG  1558378770        92 -13.19
# 3        88      cidreira           0      BR  1558378770        66 -30.17
# 4       138     morondava           0      MG  1558378780        69 -20.30
# 5       139         vaini           0      IN  1558378780        88  15.34
# 6       176         nador           0      MA  1558378499        40  35.17
# 7       268        dingle           4      PH  1558378836        80  11.00
# 8       297         mogok           0      MM  1558378844        51  22.92
# 9       402       sambava           7      MG  1558378871        99 -14.27
# 10      444       birjand           0      IR  1558378880        26  32.86
# 11      494         baylo           1      PH  1558378889        69   7.85
#
#        Lng  MaxTemp  Wind Speed
# 1   -46.00    73.68        5.32
# 2    49.05    74.76        4.52
# 3   -50.22    76.56        5.50
# 4    44.28    79.08        9.06
# 5    74.49    78.90        1.59
# 6    -2.93    75.20        6.93
# 7   122.67    79.08        2.73
# 8    96.51    72.24        2.77
# 9    50.17    70.98        1.50
# 10   59.22    71.60        9.17
# 11  126.06    77.00        1.07

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_locs = df_sub.loc[:, ["Lat", "Lng"]].values[0]
hotel_locs
# Out:
# array([-20.63, -46.  ])

# %%
# utilize code from Google lesson and also group 4 project. 

target_coordinates = f"{hotel_locs[0]}, {hotel_locs[1]}"
target_search = "hotel"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

response.url
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-20.63%2C+-46.0&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4'

# %%
places_data = response.json()
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uED3Od1gvuh1790pn43_Q-Qe2m7d2XBiuZLVlhxypd9l73CLYj17pGiRui2GzA3l-NdIoBvAEtLETh64ug03jPUCM2DeqrhrZQ_nIk7vRnJZCPPcf4cDYQx1YBWACnHTdEmXeke19SLQZpnYRj9wTniJnH4Evyo2Sv6dKgj4ziKjf2jgHV7UmbV4S_hKxjt0npBZPiEpZfdZ3vCdSLonDN94dVxbbSyoRLMxWWur1UZOO4PBNynt_rcOnf4-hA_qYyUhfLTjMStabNnWbl2QJq12kXqvUT5NUFAkKz6LCY2PezoJneQfF4QjcIhhp3nL6qHldq1-AvC3LKJ6vdf7EWnGX3QOIJXchA-r8UMY9GMCCuOEwMDH6pYnDboARwuJAQZTWRlUUmJWmgQkVv7JRYJDySgRR2nDwqz66swV332dsPRqAFvXT1WlLx7dagtu_Q",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6425523,
#                     "lng": -46.00563959999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.64119272010728,
#                         "lng": -46.00434157010727
#                     },
#                     "southwest": {
#                         "lat": -20.64389237989272,
#                         "lng": -46.00704122989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Pousada Su\u00edtes do Lago",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 512,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103028673385193490244\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uECSC6DleNJQLBiZKNSdcG3zGXKDEeYdA58HvwdvBfJqaHzj_-z37hwaPTpy2oivAdqkj0XTwQPcHEwJVvRD-PceT-XUf8JK2T4euOW6ovl9T8Xj9usQB88pTDmAF1LgrOVyuyedO4J8KKPcQc3zknobFEjkS_FKjYirxH_VyJXj-sbY",
#                     "width": 812
#                 }
#             ],
#             "place_id": "ChIJISPGczw9tJQR2xLBO9BKTJQ",
#             "plus_code": {
#                 "compound_code": "9X4V+XP Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X4V+XP"
#             },
#             "rating": 4.6,
#             "reference": "ChIJISPGczw9tJQR2xLBO9BKTJQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 48,
#             "vicinity": "R. dos Remos, 432, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6289793,
#                     "lng": -46.0285609
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.62777447010728,
#                         "lng": -46.02738632010728
#                     },
#                     "southwest": {
#                         "lat": -20.63047412989272,
#                         "lng": -46.03008597989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Escarpas Resort",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111319234340209745470\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEBSnxQd5PBZ4mX_elngzW6Wyz3ExxgeuSjaiGS4rkjJbIz-IzT9TLD0lir5pXQwmLYNJGa4KNZ13789zfY3kWjgnO7LcRJEQ6M3nbA8UIVOGjg46YZ6o_0ydebadobze0hS5o_5LRv24xH4_NJJ34CxpMjEzsI5IbWNQTtxhmf3aLdF",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJb1bFCO48tJQR6Nw2j-8BALQ",
#             "plus_code": {
#                 "compound_code": "9XCC+CH Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XCC+CH"
#             },
#             "rating": 4.7,
#             "reference": "ChIJb1bFCO48tJQR6Nw2j-8BALQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 625,
#             "vicinity": "R. das \u00c2ncoras, 1505 - CENTRO, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6456114,
#                     "lng": -46.0097467
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.64429397010727,
#                         "lng": -46.00845397010728
#                     },
#                     "southwest": {
#                         "lat": -20.64699362989272,
#                         "lng": -46.01115362989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Hotel Escarpas do Lago",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102771479077732161127\">Escarpas Turismo</a>"
#                     ],
#                     "photo_reference": "Aap_uECTW6uuFwkXoEaC8W_jcOu6lr-jN2Z2UILOVJxPfwYJEyx_agb1bA298xIk0L2NuR5Cktxe1GE4oXvHP02rx5y6E-CyjG8V-HVkZsBDvqz_5A2cP342ReSaRRfBpnRaTkJPWk6jgZSAKANNZZG_M2ct-3feNwdCvD28sw_kvbNJvSLp",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJx8uifYE7tJQRf98euuRPbR4",
#             "plus_code": {
#                 "compound_code": "9X3R+Q4 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X3R+Q4"
#             },
#             "rating": 4.2,
#             "reference": "ChIJx8uifYE7tJQRf98euuRPbR4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 972,
#             "vicinity": "Avenida das Caravelas, Engenheiro Jos\u00e9 Mendes J\u00fanior, 25 - Escarpas do Lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6331634,
#                     "lng": -46.0303382
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63195277010728,
#                         "lng": -46.02908047010727
#                     },
#                     "southwest": {
#                         "lat": -20.63465242989272,
#                         "lng": -46.03178012989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Kanto Island Inn Suites & Spa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2848,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103273964572684594071\">Pousada Kanto da Ilha Suites &amp; Spa</a>"
#                     ],
#                     "photo_reference": "Aap_uEDPHW8H_FQ87KGVMg951kXJSnxEzxCdBub6vPHIxu-g-x4D0uc_L4_h6e-qdVxL80SXN69ZX532wIXpM-AgsKfdc4PSt4VD7t1EA6R76WKvlH_DGymfN7-UgBMmNVqMwyDpUmJJioMZvYjuF8akU85V-xX7-zYi97bhEUK-adSXzeST",
#                     "width": 4288
#                 }
#             ],
#             "place_id": "ChIJm_NL--w8tJQR8vHCUJO_GGs",
#             "plus_code": {
#                 "compound_code": "9X89+PV Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X89+PV"
#             },
#             "rating": 4.7,
#             "reference": "ChIJm_NL--w8tJQR8vHCUJO_GGs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 331,
#             "vicinity": "R. Vicente Paulo Ramos - \u00c1guas das Vertentes, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6183873,
#                     "lng": -46.0491482
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61700662010728,
#                         "lng": -46.04779677010728
#                     },
#                     "southwest": {
#                         "lat": -20.61970627989272,
#                         "lng": -46.05049642989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Pousada Buena Vista",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2940,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113385812944770937976\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uECB7JNibkMdq2gWFYfFUQ-peArgjI-XhtEnhgTCPUez2yN5xcKUHkViav0eP248K427c_AxTHiWtb36rS_77rYSfM9lckwLUxZoOeWxxyTgapZvjZdldP5JHKucDNn41bXoLBR4YpMDXoUMklp9fT8Bi4S7_1Ec5CDNOXtpfB-cmz-W",
#                     "width": 3920
#                 }
#             ],
#             "place_id": "ChIJ4czP7WA9tJQRTwhKsMUiDnw",
#             "plus_code": {
#                 "compound_code": "9XJ2+J8 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XJ2+J8"
#             },
#             "rating": 4.8,
#             "reference": "ChIJ4czP7WA9tJQRTwhKsMUiDnw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 113,
#             "vicinity": "R. Jos\u00e9 Pedro Ratis, 420 - Bela vista, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.648217,
#                     "lng": -46.0088593
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.64687072010728,
#                         "lng": -46.00760167010728
#                     },
#                     "southwest": {
#                         "lat": -20.64957037989272,
#                         "lng": -46.01030132989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Hostel Escarpas do Lago",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1534,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100484267240597892695\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uECdqYYG3USuUnYPMW2pWVlk5wKxYXBDojC1rfIrjT9d0J6oSWApyaX0PIegsHrlwlqJbqTa7pcv21q_hAIY7CdkJVV9HSxBv5Xlh3jEC5LGuNWR4GGq5Fq2yn2V-roJwP8OTb9nqsqNepE0vbWlIujB0RJCURDxDi1IkBs9VyXTGvi3",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ6yyJly89tJQRQEmddxiGHQA",
#             "plus_code": {
#                 "compound_code": "9X2R+PF Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X2R+PF"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ6yyJly89tJQRQEmddxiGHQA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 96,
#             "vicinity": "Av. das Caravelas, 325 - Escarpas do Lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6326503,
#                     "lng": -46.0295906
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63136037010728,
#                         "lng": -46.02827152010728
#                     },
#                     "southwest": {
#                         "lat": -20.63406002989273,
#                         "lng": -46.03097117989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Pousada Viver Capit\u00f3lio",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113919254406709850131\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEAsEeylZM6kvufPEpUgeWBL7pSbqN7xe2gocm9F_3rRwVB7FanaNhilhiRm3d6OCl_q51-kqtb9F7LtYgbTmI2XuJ99ex1QnqF-fR63MCRJXnZr4k7UwRw4Gjgg0SaAlWqdnuVnOHKwlqctVkVaKYr3MO2DL2JhJXc5kL8rjSqgiuE5",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJA7HJmTk9tJQRpxuqhiLzlGE",
#             "plus_code": {
#                 "compound_code": "9X8C+W5 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X8C+W5"
#             },
#             "rating": 4.7,
#             "reference": "ChIJA7HJmTk9tJQRpxuqhiLzlGE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 83,
#             "vicinity": "R. Clotilde Hort\u00eancio Ramos, 565 - \u00c1guas das Vertentes, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6550844,
#                     "lng": -46.0122909
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.65376897010728,
#                         "lng": -46.01094677010727
#                     },
#                     "southwest": {
#                         "lat": -20.65646862989272,
#                         "lng": -46.01364642989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Camaleao Hostel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107302782508479813524\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEC1VMzTV63Ajs8xA_l550X-Hk0WOiTa2H1akUL2XkAHpThEuSKqiRKyjNpo5eCgkGMKhUUI1ImC2cfw2-QAkeVNLJ2-ujy2fBPrI_MN8bheooThkP_OMR7JOOV3G-j4ANoIcESSt0YeyNYN3xjTrOW1XsdQp-_b69t1RjnDethv80mL",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJEwZ2X4Q7tJQRuPg2b12dDUo",
#             "plus_code": {
#                 "compound_code": "8XVQ+X3 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM8XVQ+X3"
#             },
#             "rating": 4.7,
#             "reference": "ChIJEwZ2X4Q7tJQRuPg2b12dDUo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 115,
#             "vicinity": "Condominio, R. das Balsas, 220 - Escarpas do Lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6342407,
#                     "lng": -45.9994931
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63284097010727,
#                         "lng": -45.99814092010728
#                     },
#                     "southwest": {
#                         "lat": -20.63554062989272,
#                         "lng": -46.00084057989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Yurta Glamping",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2146,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112909226234723213782\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEAgGJgTCWbPP_ExZ8gono5-ANmUz5j_unVW6unMaW8QQ_eoypj57rZheTXgTMMWBThbZRb_M1mVzKZxi6BJePbMqgi1Udj0gMAF852zu9BRGCUNdecdomPPJ6Zd-HtlcdJrIzibDuvnVG2fDEgeEfTnnqou-7x-nZ9ytpLPS4aGAr_q",
#                     "width": 3816
#                 }
#             ],
#             "place_id": "ChIJn34PZog9tJQRjFNSJwP4SHw",
#             "plus_code": {
#                 "compound_code": "9282+86 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FP9282+86"
#             },
#             "rating": 5,
#             "reference": "ChIJn34PZog9tJQRjFNSJwP4SHw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 30,
#             "vicinity": "R. Marte, 270 - Ponta do Sol, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.618983,
#                     "lng": -46.0501616
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61753447010728,
#                         "lng": -46.04880642010727
#                     },
#                     "southwest": {
#                         "lat": -20.62023412989272,
#                         "lng": -46.05150607989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Hostel Capitol Paradise",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110460564956641468925\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEABuSasR4lJMrKyH0RFxnAj6IBnpzC-qGMVuACkmeH8o4ZWgaZlFb4BLVseM5iQUfEu7EXFNpOYqSi1p0SL9tHxcjhxNjOpXPhSAXDKlM4f0i8CPzSXLWr7IN_zVl6dUsRGybkQpU-ODH9UGKvKC9jNwwdUDJau_KiU053kUNGWqhbw",
#                     "width": 5184
#                 }
#             ],
#             "place_id": "ChIJITYHGSk9tJQRDeKUhn2Vjwk",
#             "plus_code": {
#                 "compound_code": "9WJX+CW Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9WJX+CW"
#             },
#             "rating": 4.7,
#             "reference": "ChIJITYHGSk9tJQRDeKUhn2Vjwk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 209,
#             "vicinity": "R. Ant\u00f4nio da Mata Oliveira, 130 F - Bela Vista, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.631539,
#                     "lng": -46.0327344
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63012367010728,
#                         "lng": -46.03135172010728
#                     },
#                     "southwest": {
#                         "lat": -20.63282332989272,
#                         "lng": -46.03405137989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Pousada do Batata",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118015720460896287737\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEDK2stI2FjfvXwxyaO2_9mr--MNZpjfVwp3es5RgzMHXKZoi-BkZUN1T7x6_Z6XaT2rNw2XO4eMAdytl-T30ySWNd0j7C159JLuw7b-MRGCYRDzoMhboDar4Oo5rIeXjYWtfaMauGIlt9Y3UAZavxXu18hQ6Lmv4tcBWg8d71FlVDty",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJW6WoFP49tJQRdPEj3L37cBo",
#             "plus_code": {
#                 "compound_code": "9X98+9W Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X98+9W"
#             },
#             "rating": 4.9,
#             "reference": "ChIJW6WoFP49tJQRdPEj3L37cBo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 53,
#             "vicinity": "R. Clotilde Hort\u00eancio Ramos, 440, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6336191,
#                     "lng": -46.030546
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63231247010728,
#                         "lng": -46.02916822010727
#                     },
#                     "southwest": {
#                         "lat": -20.63501212989272,
#                         "lng": -46.03186787989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Pousada Vale do Chap\u00e9u",
#             "photos": [
#                 {
#                     "height": 1702,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111103269765682818499\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEDwPyuIBF2eod7B0ArYuC-ra54FfuQaOgbaMYNwxKSEzuhMjVZUi_s-IHm2RU5GkE5m4mbNRl6eYjq95F3iR0XYMM-BAlozmQd5JSZxnfDzjRRsvdtZybfCU4tIl3ZyKNBUjnkwS8xxjJXuSIdiJJKS_obHw3ljKDcE_4ZjvJMoVCeK",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJnU8z5Ow8tJQRQJxdVi2TsHQ",
#             "plus_code": {
#                 "compound_code": "9X89+HQ Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X89+HQ"
#             },
#             "rating": 4.9,
#             "reference": "ChIJnU8z5Ow8tJQRQJxdVi2TsHQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 181,
#             "vicinity": "Estrada Capit\u00f3lio KM 2,5 - Condom\u00ednio do Gat\u00e3o - Escarpas do Lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6043228,
#                     "lng": -46.0490313
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.60287977010728,
#                         "lng": -46.04767802010728
#                     },
#                     "southwest": {
#                         "lat": -20.60557942989272,
#                         "lng": -46.05037767989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Pousada Quinta dos Cabe\u00e7as",
#             "photos": [
#                 {
#                     "height": 1287,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103183943906538954419\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEB4Pt4uIQ-gpqGyEAJPS7NI_9bOK6SMHKoNlQ6Ehm9-1ypgOITb9S9_AFluYSOKDZmWrlFLfVwpo1NIisdIpriwcFu9yPHpVBbsTzsVDQr4hqTQ3bcF8w2ZiXlZaxlm7wNWJPEUOJPS3Be2K_XiWHitWZLuC1dw01IIY9amybtZgZL-",
#                     "width": 2000
#                 }
#             ],
#             "place_id": "ChIJubmukK49tJQRIIhrCNiShF0",
#             "plus_code": {
#                 "compound_code": "9XW2+79 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XW2+79"
#             },
#             "rating": 4.7,
#             "reference": "ChIJubmukK49tJQRIIhrCNiShF0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 43,
#             "vicinity": "Estr. Vicente Conegas, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6138896,
#                     "lng": -46.0244673
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61257452010728,
#                         "lng": -46.02311247010727
#                     },
#                     "southwest": {
#                         "lat": -20.61527417989273,
#                         "lng": -46.02581212989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Para\u00edso Capit\u00f3lio Su\u00edtes Pousada",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 869,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111961170283018491277\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEDwygagcBATMehNhn66xTdIchK1e_80bYMPHLwWGRJz4KXRL3F3CrL13RQbT88Dm10Mo9lVaTJlQkVDcWFAG5Sf3Lx2h1S5RLmT7o6QJOn9Gq99uK6fMikehMv5ziV7VLditoHNKWMlp4T4V_aCTkaWAcsNMX7gXfejO7vGTlye1hmh",
#                     "width": 1158
#                 }
#             ],
#             "place_id": "ChIJ6TvYks09tJQRV1VadQR5J_4",
#             "plus_code": {
#                 "compound_code": "9XPG+C6 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XPG+C6"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ6TvYks09tJQRV1VadQR5J_4",
#             "scope": "GOOGLE",
#             "types": [
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 358,
#             "vicinity": "Fazenda On\u00e7a , Capit\u00f3lio MG - Estrada Capit\u00f3lio - Guap\u00e9, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6213492,
#                     "lng": -46.0404692
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61998367010728,
#                         "lng": -46.03915092010728
#                     },
#                     "southwest": {
#                         "lat": -20.62268332989272,
#                         "lng": -46.04185057989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Encantos de Capitolio",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2269,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108946325875433562004\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEC5ADe8V7kF8_1fHmyYfkPK7ht9N5272b7HAuGz0Wz-7dsk6N7gLY5yQ6ixEfs-Uhw8YSvdlnJ60I13KKK_n4ReeOo7KKtwLyk7V5akltw973hn1Y41ecXU5fDkwlwudL-vcSg7j1hwAX9Frt8GLTdgmBV5EqboXM_b_2uW5KP3Dj7D",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ5XnXDQM9tJQRIcFufD6DG3k",
#             "plus_code": {
#                 "compound_code": "9XH5+FR Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XH5+FR"
#             },
#             "rating": 4.8,
#             "reference": "ChIJ5XnXDQM9tJQRIcFufD6DG3k",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 54,
#             "vicinity": "R. Jos\u00e9 Hort\u00eancio Ramos, 305 - Nova, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6357205,
#                     "lng": -45.9994997
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63437137010728,
#                         "lng": -45.99802402010728
#                     },
#                     "southwest": {
#                         "lat": -20.63707102989272,
#                         "lng": -46.00072367989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Pousada Recanto do Lago 2",
#             "photos": [
#                 {
#                     "height": 2006,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117599525625198013410\">Michel Costa</a>"
#                     ],
#                     "photo_reference": "Aap_uECGNCEniOWYgks4at-ldPnRYJfVhs9ln0d72R8dE7obllXu5BjedLkBYqVOM9MMbtgaV1nroBOxGkoSDRvcQoYonMm2tkYRbseDP1X0aFOp0D0faexSJRsVb3zZS1cJqcUyB99i40C0MixYsUoshXNFbt067FUokjrNOvwRzvuov5d3",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJLy8N7lg9tJQRwtqA7GRy0_4",
#             "plus_code": {
#                 "compound_code": "9272+P6 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FP9272+P6"
#             },
#             "rating": 4.4,
#             "reference": "ChIJLy8N7lg9tJQRwtqA7GRy0_4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 25,
#             "vicinity": "R. do Sol, 600 - Ponta do Sol, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6136832,
#                     "lng": -46.04436099999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61223662010728,
#                         "lng": -46.04298292010727
#                     },
#                     "southwest": {
#                         "lat": -20.61493627989272,
#                         "lng": -46.04568257989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Condom\u00ednio dos Lagos",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1381,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104195439060787495921\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEBdx3eGYzBd7lY9HnOwQ_-GAmm_s5rAXV-lCnUb8pa0s_EyUn5AAl4qwF410CufxdwHT4HBHBeUnyKkp2IJWJmjjvlztFLjYJsTBp4HjOnY44zl7zR8Eif7ROjqdM0gMGdSfz1y0aKnp_NqU8kTHnHpK2BM_VQ_dPifZ2X03DHFw848",
#                     "width": 720
#                 }
#             ],
#             "place_id": "ChIJdwj6axo9tJQR1OrtwBOwGFs",
#             "plus_code": {
#                 "compound_code": "9XP4+G7 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XP4+G7"
#             },
#             "rating": 5,
#             "reference": "ChIJdwj6axo9tJQR1OrtwBOwGFs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "R. M\u00e1rio Jos\u00e9 de Oliveira, 250, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6171339,
#                     "lng": -46.028331
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61569927010727,
#                         "lng": -46.02701122010728
#                     },
#                     "southwest": {
#                         "lat": -20.61839892989272,
#                         "lng": -46.02971087989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Pousada Carneirinho",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1503,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110817391236166630889\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEDLMzyr5viX7FGQW9PWRwxVR2MZYk4u4yMNgU3IXygH08xkdJlnq9kqu66ckvEgNoKyw7brAevajQydM5cEZEw3CZrvWpMxGwC29FVUeUV1ABl8Ji_JM0D5ggHcJ-nSYGyc1PWKms9bhVBGFGahLN0cr3wj3CGuQ_KYIZE9r4Krhfy9",
#                     "width": 1503
#                 }
#             ],
#             "place_id": "ChIJiZ7as7s9tJQR8oVTNGqRJNs",
#             "plus_code": {
#                 "compound_code": "9XMC+4M Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XMC+4M"
#             },
#             "rating": 4.6,
#             "reference": "ChIJiZ7as7s9tJQR8oVTNGqRJNs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 134,
#             "vicinity": "R. Mangueiras, 430, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6495586,
#                     "lng": -46.0093067
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.64820577010728,
#                         "lng": -46.00790862010727
#                     },
#                     "southwest": {
#                         "lat": -20.65090542989272,
#                         "lng": -46.01060827989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Casa no mirante de Escarpas",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 666,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110595972291913993919\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEDeDHbrLvUOjOk9mp6FqDtcsgt7EbIe3mAwbYMtBsa0nT051lh0x6l-O5n996bfxfS6nRyxlyC_uQqfrOyYf3pKNyTfqtEa8oRhHuvpBuCZdHX_Qrucxzk6fp6U1eyNxc8SQ-ghmoVHd8bLiIqmuGnBcdp1N-tb8nDyyJ7Uv5U-WeSR",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJs2RfiaI7tJQR1i6B2hsxm9o",
#             "plus_code": {
#                 "compound_code": "9X2R+57 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X2R+57"
#             },
#             "rating": 5,
#             "reference": "ChIJs2RfiaI7tJQR1i6B2hsxm9o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Av. das Caravelas, 510 - Escarpas do lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6147287,
#                     "lng": -46.0492138
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61334207010728,
#                         "lng": -46.04786247010728
#                     },
#                     "southwest": {
#                         "lat": -20.61604172989272,
#                         "lng": -46.05056212989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Casa Capit\u00f3lio I",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107361163848595680642\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEASRLBYgVcMlU0OObRFS-0eZzqQXo0C4_SFNl_CxZ8t3_37CBJ9prbF1ga7w3wR2RoqmyqM44VPjMrs-J8hT-45Pnd4ReJTKOyMzamE_DDq39SmUVOncadct9ut6b91hYsny6xXV2VapY-7KEG9Sn_z__z0jENH0F3OL3ztfpxJ_7uP",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ425orC89tJQRHyG-0XejQLk",
#             "plus_code": {
#                 "compound_code": "9XP2+48 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XP2+48"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ425orC89tJQRHyG-0XejQLk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 135,
#             "vicinity": "R. Cel. Louren\u00e7o Belo, 227, Capit\u00f3lio"
#         }
#     ],
#     "status": "OK"
# }

# %%
places_data["results"][0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': -20.6425523, 'lng': -46.00563959999999},
#   'viewport': {'northeast': {'lat': -20.64119272010728,
#     'lng': -46.00434157010727},
#    'southwest': {'lat': -20.64389237989272, 'lng': -46.00704122989272}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#  'icon_background_color': '#909CE1',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#  'name': 'Pousada Suítes do Lago',
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 512,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103028673385193490244">A Google User</a>'],
#    'photo_reference': 'Aap_uECSC6DleNJQLBiZKNSdcG3zGXKDEeYdA58HvwdvBfJqaHzj_-z37hwaPTpy2oivAdqkj0XTwQPcHEwJVvRD-PceT-XUf8JK2T4euOW6ovl9T8Xj9usQB88pTDmAF1LgrOVyuyedO4J8KKPcQc3zknobFEjkS_FKjYirxH_VyJXj-sbY',
#    'width': 812}],
#  'place_id': 'ChIJISPGczw9tJQR2xLBO9BKTJQ',
#  'plus_code': {'compound_code': '9X4V+XP Capitólio, State of Minas Gerais, Brazil',
#   'global_code': '58FM9X4V+XP'},
#  'rating': 4.6,
#  'reference': 'ChIJISPGczw9tJQR2xLBO9BKTJQ',
#  'scope': 'GOOGLE',
#  'types': ['lodging', 'point_of_interest', 'establishment'],
#  'user_ratings_total': 48,
#  'vicinity': 'R. dos Remos, 432, Capitólio'}

# %%
names = []
addresses = []
location_codes = []
ratings = []

for _, row in df_sub.iterrows():
    # geocoordinates
    target_coordinates = f"{row['Lat']}, {row['Lng']}"
    target_search = "hotel"
    target_radius = 5000
    target_type = "lodging"

    # set up a parameters dictionary
    params = {
        "location": target_coordinates,
        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": g_key
    }

    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params)

    print(response.url)
    # convert response to json
    places_data = response.json()
    
    try:
        name = places_data["results"][0]["name"]
        address = places_data["results"][0]["vicinity"]
        location_code = places_data["results"][0]["plus_code"]["compound_code"]
        rating = places_data["results"][0]["rating"]
    
        names.append(name)
        addresses.append(address)
        location_codes.append(location_code)
        ratings.append(rating)
    except:
        names.append("")
        addresses.append("")
        location_codes.append("")
        ratings.append(np.nan)
        
    time.sleep(1)
        
        
df_sub["hotel"] = names
df_sub["hotel_address"] = addresses
df_sub["hotel_location_code"] = location_codes
df_sub["rating"] = ratings

df_sub["hotel_full_address"] = df_sub["hotel_address"] + " " + df_sub["hotel_location_code"]
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-20.63%2C+-46.0&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-13.19%2C+49.05&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-30.17%2C+-50.22&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-20.3%2C+44.28&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=15.34%2C+74.49&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.17%2C+-2.93&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=11.0%2C+122.67&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=22.92%2C+96.51&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-14.27%2C+50.17&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.86%2C+59.22&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=7.85%2C+126.06&keyword=hotel&radius=5000&type=lodging&key=AIzaSyAadzfieTnAAhsO7NaaBENRuHs-UPAChs4

# %%
df_sub
# Out:
#     City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 1        70  ponta do sol           0      BR  1558378767        57 -20.63
# 2        87      ambilobe           2      MG  1558378770        92 -13.19
# 3        88      cidreira           0      BR  1558378770        66 -30.17
# 4       138     morondava           0      MG  1558378780        69 -20.30
# 5       139         vaini           0      IN  1558378780        88  15.34
# 6       176         nador           0      MA  1558378499        40  35.17
# 7       268        dingle           4      PH  1558378836        80  11.00
# 8       297         mogok           0      MM  1558378844        51  22.92
# 9       402       sambava           7      MG  1558378871        99 -14.27
# 10      444       birjand           0      IR  1558378880        26  32.86
# 11      494         baylo           1      PH  1558378889        69   7.85
#
#        Lng  MaxTemp  Wind Speed                    hotel  \
# 1   -46.00    73.68        5.32   Pousada Suítes do Lago
# 2    49.05    74.76        4.52           Hotel National
# 3   -50.22    76.56        5.50            Hotel Castelo
# 4    44.28    79.08        9.06
# 5    74.49    78.90        1.59
# 6    -2.93    75.20        6.93  Hôtel Mercure Rif Nador
# 7   122.67    79.08        2.73
# 8    96.51    72.24        2.77
# 9    50.17    70.98        1.50         Hôtel Las Palmas
# 10   59.22    71.60        9.17
# 11  126.06    77.00        1.07
#
#                                    hotel_address  \
# 1                   R. dos Remos, 432, Capitólio
# 2                                    6, Ambilobe
# 3   R. Osvaldo Aranha, 3968 - CIDREIRA, Cidreira
# 4
# 5
# 6                   1 Avenue Ibn Tachfine, Nador
# 7
# 8
# 9                                        Sambava
# 10
# 11
#
#                                   hotel_location_code  rating  \
# 1    9X4V+XP Capitólio, State of Minas Gerais, Brazil     4.6
# 2                        R23X+JP Ambilobe, Madagascar     3.5
# 3   RQCW+RH CIDREIRA, Cidreira - State of Rio Gran...     4.3
# 4                                                         NaN
# 5                                                         NaN
# 6                              53HH+C6 Nador, Morocco     4.3
# 7                                                         NaN
# 8                                                         NaN
# 9                         P5Q8+64 Sambava, Madagascar     3.2
# 10                                                        NaN
# 11                                                        NaN
#
#                                    hotel_full_address
# 1   R. dos Remos, 432, Capitólio 9X4V+XP Capitólio...
# 2            6, Ambilobe R23X+JP Ambilobe, Madagascar
# 3   R. Osvaldo Aranha, 3968 - CIDREIRA, Cidreira R...
# 4
# 5
# 6   1 Avenue Ibn Tachfine, Nador 53HH+C6 Nador, Mo...
# 7
# 8
# 9                 Sambava P5Q8+64 Sambava, Madagascar
# 10
# 11

# %%
hotel_df = df_sub.dropna()

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{hotel}</dd>
<dt>Name</dt><dd>{rating}</dd>
<dt>Name</dt><dd>{hotel_full_address}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

figure_layout = {
    'width': '800px',
    'height': '400px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(map_type="HYBRID", layout=figure_layout)
heatmap_layer = gmaps.heatmap_layer(
    cleaned_df[['Lat', 'Lng']], weights=cleaned_df['Humidity'],
    max_intensity=500, point_radius=10, dissipating = False
)
fig.add_layer(heatmap_layer)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

fig
# Display figure
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='400px', margin='0 auto 0 auto', padding='1px', wi…
